# %% [markdown]
# # Proyecto práctico
#
# ## Unidad 3 - Aprendizaje supervisado
#
# El proyecto práctico consiste en abordar un problema de clasificación de documentos textuales. Tenemos a nuestra disposición un dataset de noticias de prensa en español publicada por el medio "CNN Chile".
#
# Las noticias están divididas en 7 categorías temáticas: *'pais','deportes','tendencias','tecnologias','cultura','economia','mundo'*
#
# El proyecto se divide en dos partes:
#
# - Utilizar al menos 3 estrategías para entrenar modelos de clasificación capaces de clasificar las noticias según su categoría temática.
#
# - Explorar cuáles son las características que permiten explicar las decisiones de su modelo.
#
# ## 0. Evaluación
#
# El proyecto se realiza de forma individual. Se entrega a más tardar el **lunes 30 de noviembre** en su repositorio GitHub.
#
# **Pauta de evaluación:**
#
# Competencia 1: Aplicar un protocolo de aprendizaje supervisado para resolver un problema clasificación estandar, utilizando un entorno de programación en Python
#
# - < 2 : El protocolo de aprendizaje supervisado utilizado es incompleto y/o presenta errores importantes
# - 2 a 3.9 : El protocolo de aprendizaje supervisado utilizado es incompleto o presenta un error importante
# - 4 a 5.5 : El protocolo de aprendizaje es completo, no tiene error, pero las estrategias utilizadas son relativamente simples y el rendimiento de los modelos es perfectible.
# - 5.6 a 7.0 : El protocolo de aprendizaje es completo, no tiene error y al menos una de las estrategias utilizadas a necesitado un trabajado más avanzado y/o permite obtener un mejor rendimiento.
#
# Competencia 2: Explicar el rendimiento de un modelo de clasificación aplicando un protocolo de evaluación Precision/Recall/F-Score
#
# - < 2 : El trabajo no presenta explicaciones del rendimiento de los modelos de clasificación
# - 2 a 3.9 : El trabajo presenta algunas explicaciones pero tienen errores.
# - 4 a 5.5 : El trabajo presenta explicaciones correctas del rendimiento de los modelos
# - 5.6 a 7 : El trabajo presenta explicaciones correctas del rendimiento de los modelos y además presenta un método para explicar las decisiones/errores

# %% [markdown]
# ## 1. Dataset

# %%
import pandas as pd

df = pd.read_csv('cnnchile_7000.csv')
df
# Out:
#      country media_outlet                                                url  \
# 0      chile     cnnchile  https://www.cnnchile.com/pais/pdta-del-colegio...
# 1      chile     cnnchile  https://www.cnnchile.com/pais/defensoria-ninez...
# 2      chile     cnnchile  https://www.cnnchile.com/pais/cuanto-les-pagar...
# 3      chile     cnnchile  https://www.cnnchile.com/pais/sobrino-de-aleja...
# 4      chile     cnnchile  https://www.cnnchile.com/pais/analisis-sobre-e...
# 5      chile     cnnchile  https://www.cnnchile.com/pais/encuesta-liberta...
# 6      chile     cnnchile  https://www.cnnchile.com/pais/presidenta-decre...
# 7      chile     cnnchile  https://www.cnnchile.com/pais/autoridades-de-t...
# 8      chile     cnnchile  https://www.cnnchile.com/pais/polemica-por-can...
# 9      chile     cnnchile  https://www.cnnchile.com/pais/interponen-nueva...
# 10     chile     cnnchile  https://www.cnnchile.com/pais/corporacion-quer...
# 11     chile     cnnchile  https://www.cnnchile.com/pais/ejecutivos-enap-...
# 12     chile     cnnchile  https://www.cnnchile.com/pais/pdta-bachelet-y-...
# 13     chile     cnnchile  https://www.cnnchile.com/pais/los-derechos-de-...
# 14     chile     cnnchile  https://www.cnnchile.com/pais/nuevos-anteceden...
# 15     chile     cnnchile  https://www.cnnchile.com/pais/cuenta-publica-l...
# 16     chile     cnnchile  https://www.cnnchile.com/pais/amnistia-interna...
# 17     chile     cnnchile  https://www.cnnchile.com/pais/viveros-por-puen...
# 18     chile     cnnchile  https://www.cnnchile.com/pais/leopoldo-perez-a...
# 19     chile     cnnchile  https://www.cnnchile.com/pais/chile-cae-un-pue...
# 20     chile     cnnchile  https://www.cnnchile.com/pais/psu-el-origen-de...
# 21     chile     cnnchile  https://www.cnnchile.com/pais/puntaje-nacional...
# 22     chile     cnnchile  https://www.cnnchile.com/pais/senador-navarro-...
# 23     chile     cnnchile  https://www.cnnchile.com/pais/nueva-mayoria-co...
# 24     chile     cnnchile  https://www.cnnchile.com/pais/el-debate-sobre-...
# 25     chile     cnnchile  https://www.cnnchile.com/pais/sistema-frontal-...
# 26     chile     cnnchile  https://www.cnnchile.com/pais/la-importancia-d...
# 27     chile     cnnchile  https://www.cnnchile.com/pais/el-analisis-a-la...
# 28     chile     cnnchile  https://www.cnnchile.com/pais/javiera-suarez-a...
# 29     chile     cnnchile  https://www.cnnchile.com/pais/caso-penta-delan...
# ...      ...          ...                                                ...
# 6970   chile     cnnchile  https://www.cnnchile.com/tecnologias/fronteras...
# 6971   chile     cnnchile  https://www.cnnchile.com/tecnologias/chile-pot...
# 6972   chile     cnnchile  https://www.cnnchile.com/tecnologias/experto-p...
# 6973   chile     cnnchile  https://www.cnnchile.com/tecnologias/las-empre...
# 6974   chile     cnnchile  https://www.cnnchile.com/tecnologias/elon-musk...
# 6975   chile     cnnchile  https://www.cnnchile.com/tecnologias/como-apro...
# 6976   chile     cnnchile  https://www.cnnchile.com/tecnologias/generacio...
# 6977   chile     cnnchile  https://www.cnnchile.com/tecnologias/review-cn...
# 6978   chile     cnnchile  https://www.cnnchile.com/tecnologias/libra-nue...
# 6979   chile     cnnchile  https://www.cnnchile.com/tecnologias/las-visio...
# 6980   chile     cnnchile  https://www.cnnchile.com/tecnologias/nintendo-...
# 6981   chile     cnnchile  https://www.cnnchile.com/tecnologias/lamborghi...
# 6982   chile     cnnchile  https://www.cnnchile.com/tecnologias/feria-int...
# 6983   chile     cnnchile  https://www.cnnchile.com/tecnologias/fronteras...
# 6984   chile     cnnchile  https://www.cnnchile.com/tecnologias/creadores...
# 6985   chile     cnnchile  https://www.cnnchile.com/tecnologias/iniciativ...
# 6986   chile     cnnchile  https://www.cnnchile.com/tecnologias/el-traile...
# 6987   chile     cnnchile  https://www.cnnchile.com/tecnologias/usuarios-...
# 6988   chile     cnnchile  https://www.cnnchile.com/tecnologias/sony-desc...
# 6989   chile     cnnchile  https://www.cnnchile.com/tecnologias/la-nasa-e...
# 6990   chile     cnnchile  https://www.cnnchile.com/tecnologias/data-empr...
# 6991   chile     cnnchile  https://www.cnnchile.com/tecnologias/peliculas...
# 6992   chile     cnnchile  https://www.cnnchile.com/tecnologias/perez-acl...
# 6993   chile     cnnchile  https://www.cnnchile.com/tecnologias/la-ultima...
# 6994   chile     cnnchile  https://www.cnnchile.com/tecnologias/las-mujer...
# 6995   chile     cnnchile  https://www.cnnchile.com/tecnologias/playstati...
# 6996   chile     cnnchile  https://www.cnnchile.com/tecnologias/android-l...
# 6997   chile     cnnchile  https://www.cnnchile.com/tecnologias/regalos-t...
# 6998   chile     cnnchile  https://www.cnnchile.com/tecnologias/jugar-con...
# 6999   chile     cnnchile  https://www.cnnchile.com/tecnologias/konami-la...
#
#                                                   title  \
# 0     Pdta. del Colegio de Matronas explicó los ries...
# 1     Defensoría de la Niñez pide al Estado velar po...
# 2            ¿Cuánto les pagarán a los vocales de mesa?
# 3     Sobrino de Alejandro Navarro intenta “funar” e...
# 4     Análisis sobre el aumento de impuestos para al...
# 5     Encuesta Libertad y Desarrollo: Temor a perder...
# 6     Presidenta decretó zona de catástrofe para reg...
# 7     Autoridades de Transporte anunciaron nuevos bu...
# 8             Polémica por cantidad de casas destruidas
# 9     Interponen nueva demanda contra CCU por prácti...
# 10    Corporación “Queremos ser padres” se manifestó...
# 11    6 ejecutivos de ENAP serán formalizados por de...
# 12    Pdta. Bachelet y Fundación Thompkins firmaron ...
# 13    Los derechos de salud que regularizará el Acue...
# 14                   Nuevos antecedentes en caso Cheyre
# 15    Cuenta pública: Las propuestas para las zonas ...
# 16    Amnistía Internacional llamó a defender los DD...
# 17    Viveros por Puente Chacao: “No hay estudios de...
# 18    Leopoldo Pérez aseguró que aún existen “falenc...
# 19    Chile cae un puesto en el ránking de los paíse...
# 20                  PSU: El origen del ránking de notas
# 21    Puntaje nacional en Matemáticas: “Estudiar en ...
# 22    Senador Navarro: “Lo categórico del canciller ...
# 23    Nueva Mayoría conmemorará triunfo del NO en ac...
# 24    El debate sobre privacidad y protección legal ...
# 25    Se acerca un nuevo sistema frontal: Anuncian l...
# 26                        La importancia de las vacunas
# 27    El análisis a la Estrategia Nacional de Energí...
# 28    Javiera Suárez aseguró que le fue increíble en...
# 29    Caso Penta: Délano y Lavín reconocen aportes a...
# ...                                                 ...
# 6970  Fronteras de la Comunicación: La evolución de ...
# 6971  Con presencia de autoridades, se presentó a Ch...
# 6972  Experto profundizó en el error de programación...
# 6973  “Las empresas grandes se están tomando muy ens...
# 6974  Elon Musk vuelve a criticar a Facebook: Es “ab...
# 6975           Cómo aprovechar el celular en vacaciones
# 6976  “Generación C”: La influencia de la tecnología...
# 6977  Review CNN: La potencia del notebook ultradelg...
# 6978  Todo lo que tienes que saber sobre Libra, la c...
# 6979  Las visiones sobre los límites del uso de Phot...
# 6980  Nintendo Switch ya está disponible en todo el ...
# 6981  Lamborghini 88 Tauri: El teléfono inteligente ...
# 6982  Feria internacional “Synergy 2014” se realiza ...
# 6983  Fronteras de la Comunicación: “Cómo Twitter in...
# 6984  “Creadores”: La difusión de obras de artistas ...
# 6985  Iniciativa de redes sociales convoca a subirse...
# 6986      El tráiler de historia para ‘Mortal Kombat X’
# 6987  Usuarios informaron fallas en conexión de What...
# 6988  Sony descontinuará la Playstation 2 en Japón m...
# 6989         La NASA ensaya expedición a marte en Chile
# 6990  Data Emprendimiento, la plataforma que permite...
# 6991  YouTube ofrecerá películas completas totalment...
# 6992  Perez-Acle: “Tenemos que invertir más en cienc...
# 6993             La última acusación contra el iPhone 6
# 6994  Las mujeres que se abren paso en la industria ...
# 6995  PlayStation 5 vs Xbox Series X: Mira la compar...
# 6996     Android le dará “una paliza” a Windows en 2013
# 6997     Regalos tecnológicos marcaron pauta en Navidad
# 6998  Jugar con Fox en Starlink vale totalmente la p...
# 6999  Konami lanza PES 2018 de forma gratuita para i...
#
#                                                    text  \
# 0     La Federación de Estudiantes de la Universidad...
# 1     La Defensoría de la Niñez emitió este domingo ...
# 2     El monto del bono es de dos tercios de Unidad ...
# 3     Una nueva polémica tiene esta carrera presiden...
# 4     Especialistas recomiendan no consumir más de 2...
# 5     Francisco Klapp profundizó en el último sondeo...
# 6     La mandataria informó que recibió mensajes de ...
# 7     El Ministro de Transporte Andrés Gómez-Lobo en...
# 8     Confución generaron los datos entregados por l...
# 9     La firma ligada al grupo Luksic habría iniciad...
# 10    La agrupación habría enviado una carta hace un...
# 11    Durante la tarde de este viernes, la Fiscalía ...
# 12    La presidenta Michelle Bachelet firmó el acuer...
# 13    Reforma al sistema de isapres: Postergan entre...
# 14    La Justicia podría reabrir el sumario por las ...
# 15    El senador Bianchi aseguró que está al debe el...
# 16    Durante este miércoles, desde la sede de Amini...
# 17    El vocero del movimiento “Defendamos Chiloé” a...
# 18    Proyecto considera sanciones para actos verbal...
# 19    Aunque mantuvo los mismos puntos del año pasad...
# 20    La prueba de selección universitaria (PSU) pri...
# 21    Este miércoles se oficializaron los resultados...
# 22    Aseveró que cree que “otras generaciones” podr...
# 23    El próximo domingo se llevará a cabo esta acti...
# 24    Video sexual de universitarios en fiesta de in...
# 25    Luego un fin de semana relativamente cálido, e...
# 26     En CNN Contigo conversamos de este tema con e...
# 27     Algunos de los objetivos de la Estrategia Nac...
# 28    La periodista de 35 años, Javiera Suárez, llev...
# 29    Los controladores de Penta, Carlos Eugenio Lav...
# ...                                                 ...
# 6970  Nuevos diseños y mejor experiencia de navegaci...
# 6971  Este 2 y 3 de octubre se llevó a cabo el Singu...
# 6972  Empresas como Google y Facebook ya implementar...
# 6973  En Chile las empresas han tomado más el peso a...
# 6974  Elon Musk volvió a criticar a Facebook. Como r...
# 6975   Apenas terminan las fiestas de fin de año, co...
# 6976  El concepto nace de los términos “conectados”,...
# 6977  En esta edición de Review CNN conversamos sobr...
# 6978  Nueva York (CNN Business)– Durante el último a...
# 6979   Los profesionales gráficos los utilizan día a...
# 6980  Tras cinco años del lanzamiento de la Wii U, q...
# 6981  El modelo se va a vender a fines de este año y...
# 6982  La muestra incluye todo tipo de tendencias tec...
# 6983  En la actualidad hay cada vez mayor interacció...
# 6984  –  En entrevista con CNN Chile, el director de...
# 6985   Para este domingo está convocado un nuevo eve...
# 6986  En abril será lanzado en PlayStation 4, Xbox O...
# 6987  Cerca de las 15:30 horas, usuarios de WhatsApp...
# 6988  Se rumorea que se anunciará la próxima consola...
# 6989  El desierto de Atacama tiene cierta similitud ...
# 6990  Con la exposición del académico del departamen...
# 6991  Ante el éxito de plataformas como Netflix, HBO...
# 6992  En medio del Congreso del Futuro se dio la not...
# 6993  En el bloque de internet abordamos la última d...
# 6994  El incremento del uso de las tecnologías y la ...
# 6995  Las compañías ya han revelado muchos detalles ...
# 6996  Se proyecta que tras un virtual empate en 2012...
# 6997  Tablets y smartphones fueron los regalos tecno...
# 6998  Crecí jugando clásicos de naves como Terminal ...
# 6999  Konami Digital Entertainment ha anunciado que ...
#
#                             date     category
# 0     2018-03-29 00:00:00.000000         pais
# 1     2020-08-02 00:00:00.000000         pais
# 2     2016-10-20 00:00:00.000000         pais
# 3     2017-11-13 00:00:00.000000         pais
# 4     2014-05-05 00:00:00.000000         pais
# 5     2015-03-30 00:00:00.000000         pais
# 6     2014-04-02 00:00:00.000000         pais
# 7     2017-02-06 00:00:00.000000         pais
# 8     2017-02-23 00:00:00.000000         pais
# 9     2013-12-04 00:00:00.000000         pais
# 10    2013-09-27 00:00:00.000000         pais
# 11    2019-10-04 00:00:00.000000         pais
# 12    2018-01-30 00:00:00.000000         pais
# 13    2015-10-02 00:00:00.000000         pais
# 14    2016-09-14 00:00:00.000000         pais
# 15    2014-05-21 00:00:00.000000         pais
# 16    2017-02-22 00:00:00.000000         pais
# 17    2016-09-11 00:00:00.000000         pais
# 18    2016-04-12 00:00:00.000000         pais
# 19    2019-01-29 00:00:00.000000         pais
# 20    2013-10-16 00:00:00.000000         pais
# 21    2018-12-26 00:00:00.000000         pais
# 22    2014-04-25 00:00:00.000000         pais
# 23    2015-10-02 00:00:00.000000         pais
# 24    2013-03-29 00:00:00.000000         pais
# 25    2019-06-25 00:00:00.000000         pais
# 26    2012-03-23 00:00:00.000000         pais
# 27    2012-02-28 00:00:00.000000         pais
# 28    2018-07-12 00:00:00.000000         pais
# 29    2015-01-08 00:00:00.000000         pais
# ...                          ...          ...
# 6970  2014-09-04 00:00:00.000000  tecnologias
# 6971  2019-10-04 00:00:00.000000  tecnologias
# 6972  2014-04-10 00:00:00.000000  tecnologias
# 6973  2011-11-17 00:00:00.000000  tecnologias
# 6974  2020-02-11 00:00:00.000000  tecnologias
# 6975  2011-12-26 00:00:00.000000  tecnologias
# 6976  2014-05-13 00:00:00.000000  tecnologias
# 6977  2017-05-22 00:00:00.000000  tecnologias
# 6978  2019-06-18 00:00:00.000000  tecnologias
# 6979  2012-01-19 00:00:00.000000  tecnologias
# 6980  2017-03-03 00:00:00.000000  tecnologias
# 6981  2014-12-12 00:00:00.000000  tecnologias
# 6982  2014-05-04 00:00:00.000000  tecnologias
# 6983  2014-11-20 00:00:00.000000  tecnologias
# 6984  2015-08-31 00:00:00.000000  tecnologias
# 6985  2012-01-05 00:00:00.000000  tecnologias
# 6986  2015-02-27 00:00:00.000000  tecnologias
# 6987  2020-07-14 00:00:00.000000  tecnologias
# 6988  2013-01-02 00:00:00.000000  tecnologias
# 6989  2016-02-27 00:00:00.000000  tecnologias
# 6990  2019-01-22 00:00:00.000000  tecnologias
# 6991  2018-11-19 00:00:00.000000  tecnologias
# 6992  2017-01-09 00:00:00.000000  tecnologias
# 6993  2014-10-07 00:00:00.000000  tecnologias
# 6994  2020-08-21 00:00:00.000000  tecnologias
# 6995  2020-09-18 00:00:00.000000  tecnologias
# 6996  2013-04-04 00:00:00.000000  tecnologias
# 6997  2012-12-26 00:00:00.000000  tecnologias
# 6998  2018-10-30 00:00:00.000000  tecnologias
# 6999  2017-11-10 00:00:00.000000  tecnologias
#
# [7000 rows x 7 columns]

# %%
from pandasql import sqldf

q="""SELECT category, count(*) FROM df GROUP BY category ORDER BY count(*) DESC;"""
result=sqldf(q)
result
# Out:
#       category  count(*)
# 0   tendencias      1000
# 1  tecnologias      1000
# 2         pais      1000
# 3        mundo      1000
# 4     economia      1000
# 5     deportes      1000
# 6      cultura      1000
